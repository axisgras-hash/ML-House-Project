# %%
# !pip install streamlit

# %%
import streamlit as st
print("Done")
# Out:
# Done

# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\salma\\House Price Project'

# %%
# cd: change drive

# %%
pip install gdown
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
